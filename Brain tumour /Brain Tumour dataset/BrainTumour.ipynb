# %% [markdown]
# #### Brain Tumour Detection

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('/Users/sharvarisoparkar/Desktop/Deep_learning_folder/Brain tumour /Brain Tumour dataset/no/1 no.jpeg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import cv2

data_path = "/Users/sharvarisoparkar/Desktop/Deep_learning_folder/Brain tumour /Brain Tumour dataset/brain_tumor_dataset"
#list of images with no tumors
Negative = os.listdir(data_path + '/no/')
#list of image with tumors
Positive = os.listdir(data_path + '/yes/')
print(f'There are {len(Negative)} MRI scans of brains with no tumor')
print(f'There are {len(Positive)} MRI scans of brains with tumor')
